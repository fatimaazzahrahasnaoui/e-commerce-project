# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# The `encoding="ISO-8859-1"` parameter in `pd.read_csv()` is used to properly read files containing special characters that may cause errors with the default `utf-8` encoding.

# %%
dataframe = pd.read_csv("non-nettoye data.csv", encoding="ISO-8859-1")

# %%
dataframe.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   20
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   20
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom   45
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   31
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   19
#
#           Location RegistrationDate     Category  Stock  Rating     Status
# 0         Lisaberg       2022-05-06     Clothing     18     4.8    Pending
# 1     Jessicahaven       2022-06-26  Electronics      9     3.9    Pending
# 2      Matthewbury       2023-01-09       Beauty     33     5.0  Delivered
# 3  North Kayleeton       2023-02-11  Electronics     86     4.2    Pending
# 4        Keithside       2023-01-27        Books     21     3.4  Cancelled

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   InvoiceNo         541909 non-null  object
#  1   StockCode         541909 non-null  object
#  2   Description       540455 non-null  object
#  3   Quantity          541909 non-null  int64
#  4   InvoiceDate       541909 non-null  object
#  5   UnitPrice         541909 non-null  float64
#  6   CustomerID        406829 non-null  float64
#  7   Country           541909 non-null  object
#  8   Age               541909 non-null  int64
#  9   Location          541909 non-null  object
#  10  RegistrationDate  541909 non-null  object
#  11  Category          541909 non-null  object
#  12  Stock             541909 non-null  int64
#  13  Rating            541909 non-null  float64
#  14  Status            541909 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 62.0+ MB

# %%
dataframe.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description           1454
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          135080
# Country                  0
# Age                      0
# Location                 0
# RegistrationDate         0
# Category                 0
# Stock                    0
# Rating                   0
# Status                   0
# dtype: int64

# %%
dataframe.loc[dataframe["Description"].isnull()].head()
# Out:
#      InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970    536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971    536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972    536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987    536549    85226A         NaN         1  12/1/2010 14:34        0.0
#
#       CustomerID         Country  Age          Location RegistrationDate  \
# 622          NaN  United Kingdom   62   New Cynthiaberg       2023-07-05
# 1970         NaN  United Kingdom   25       Jeremyhaven       2023-08-21
# 1971         NaN  United Kingdom   43          Lisaland       2022-04-18
# 1972         NaN  United Kingdom   65  West Anthonytown       2022-09-15
# 1987         NaN  United Kingdom   38        Aaronshire       2023-06-17
#
#          Category  Stock  Rating     Status
# 622         Books     71     1.3  Cancelled
# 1970  Electronics     71     3.7    Pending
# 1971         Home     23     2.3  Cancelled
# 1972  Electronics     94     3.7  Delivered
# 1987        Books     55     3.0    Pending

# %%
dataframe.loc[dataframe["CustomerID"].isnull()].head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 622   12/1/2010 11:52       0.00         NaN  United Kingdom   62
# 1443  12/1/2010 14:32       2.51         NaN  United Kingdom   29
# 1444  12/1/2010 14:32       2.51         NaN  United Kingdom   21
# 1445  12/1/2010 14:32       0.85         NaN  United Kingdom   54
# 1446  12/1/2010 14:32       1.66         NaN  United Kingdom   62
#
#                  Location RegistrationDate  Category  Stock  Rating     Status
# 622       New Cynthiaberg       2023-07-05     Books     71     1.3  Cancelled
# 1443          Kristinfurt       2023-03-05     Books     97     4.0    Pending
# 1444         Baldwinburgh       2023-06-03  Clothing      5     2.8  Cancelled
# 1445         Johnathanton       2022-09-18  Clothing      1     4.6  Delivered
# 1446  South Brittanyhaven       2023-05-23      Home     34     3.6  Delivered

# %%
dataframe.loc[dataframe['UnitPrice'] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country  Age       Location  \
# 299983  -11062.06         NaN  United Kingdom   43  New Kathystad
# 299984  -11062.06         NaN  United Kingdom   60   North Amanda
#
#        RegistrationDate Category  Stock  Rating     Status
# 299983       2022-08-12    Books     95     2.8  Cancelled
# 299984       2023-10-08   Beauty      3     4.8  Cancelled

# %%
dataframe.loc[dataframe["Quantity"]<0].head(10)
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 141   C536379         D                           Discount        -1
# 154   C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 238   C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# 239   C536391     21484        CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557   PLASTERS IN TIN VINTAGE PAISLEY        -12
# 241   C536391     22553             PLASTERS IN TIN SKULLS       -24
# 939   C536506     22960           JAM MAKING SET WITH JARS        -6
#
#          InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 141   12/1/2010 9:41      27.50     14527.0  United Kingdom   33
# 154   12/1/2010 9:49       4.65     15311.0  United Kingdom   33
# 235  12/1/2010 10:24       1.65     17548.0  United Kingdom   21
# 236  12/1/2010 10:24       0.29     17548.0  United Kingdom   32
# 237  12/1/2010 10:24       0.29     17548.0  United Kingdom   27
# 238  12/1/2010 10:24       0.29     17548.0  United Kingdom   35
# 239  12/1/2010 10:24       3.45     17548.0  United Kingdom   48
# 240  12/1/2010 10:24       1.65     17548.0  United Kingdom   21
# 241  12/1/2010 10:24       1.65     17548.0  United Kingdom   24
# 939  12/1/2010 12:38       4.25     17897.0  United Kingdom   56
#
#              Location RegistrationDate     Category  Stock  Rating     Status
# 141          Boydport       2022-02-05     Clothing     88     4.9  Delivered
# 154         East Brad       2023-03-30     Clothing     20     1.4  Cancelled
# 235      Michelleberg       2021-11-30  Electronics     83     4.6    Pending
# 236       North Sarah       2021-11-17        Books     21     2.1  Delivered
# 237    North Maryberg       2022-01-11         Home     39     1.5    Pending
# 238           Markton       2023-06-11         Toys     38     2.8  Cancelled
# 239        Wagnerport       2023-06-03         Toys     48     3.9  Cancelled
# 240  New Jonathanside       2022-08-16  Electronics     33     5.0    Pending
# 241        Andrewstad       2023-07-06         Home     71     2.6  Cancelled
# 939   Samanthaborough       2022-05-29     Clothing     73     4.9  Delivered

# %%
dataframe.loc[dataframe["StockCode"]=="m"]
# Out:
#       InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 40383    539736         m      Manual         1  12/21/2010 15:18       2.55
#
#        CustomerID         Country  Age     Location RegistrationDate Category  \
# 40383         NaN  United Kingdom   22  Williamfort       2022-12-31   Beauty
#
#        Stock  Rating     Status
# 40383     96     1.4  Cancelled

# %%
dataframe.loc[dataframe['InvoiceNo'] == 'C536379']
# Out:
#     InvoiceNo StockCode Description  Quantity     InvoiceDate  UnitPrice  \
# 141   C536379         D    Discount        -1  12/1/2010 9:41       27.5
#
#      CustomerID         Country  Age  Location RegistrationDate  Category  \
# 141     14527.0  United Kingdom   33  Boydport       2022-02-05  Clothing
#
#      Stock  Rating     Status
# 141     88     4.9  Delivered

# %% [markdown]
# null values

# %%
df_temp=dataframe.copy()

# %%
df_temp["Description"]=df_temp["Description"].fillna("no descreption")

# %%
df_temp['CustomerID'] = dataframe['CustomerID'].fillna(0)

# %%
df_temp['CustomerID'] = df_temp['CustomerID'].astype(float).astype(int)

# %%
df_temp["InvoiceDate"]=pd.to_datetime(dataframe["InvoiceDate"])

# %%
df_temp.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID          0
# Country             0
# Age                 0
# Location            0
# RegistrationDate    0
# Category            0
# Stock               0
# Rating              0
# Status              0
# dtype: int64

# %%
df_temp.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom   20
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom   20
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom   45
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom   31
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom   19
#
#           Location RegistrationDate     Category  Stock  Rating     Status
# 0         Lisaberg       2022-05-06     Clothing     18     4.8    Pending
# 1     Jessicahaven       2022-06-26  Electronics      9     3.9    Pending
# 2      Matthewbury       2023-01-09       Beauty     33     5.0  Delivered
# 3  North Kayleeton       2023-02-11  Electronics     86     4.2    Pending
# 4        Keithside       2023-01-27        Books     21     3.4  Cancelled

# %%
df_temp['InvoiceNo'] = df_temp['InvoiceNo'].astype(str)

# %%
df_temp['StockCode'] = df_temp['StockCode'].astype(str)

# %%
df_temp['Description'] = df_temp['Description'].astype(str)

# %%
df_temp['Country'] = df_temp['Country'].astype(str)

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   InvoiceNo         541909 non-null  object
#  1   StockCode         541909 non-null  object
#  2   Description       541909 non-null  object
#  3   Quantity          541909 non-null  int64
#  4   InvoiceDate       541909 non-null  datetime64[ns]
#  5   UnitPrice         541909 non-null  float64
#  6   CustomerID        541909 non-null  int64
#  7   Country           541909 non-null  object
#  8   Age               541909 non-null  int64
#  9   Location          541909 non-null  object
#  10  RegistrationDate  541909 non-null  object
#  11  Category          541909 non-null  object
#  12  Stock             541909 non-null  int64
#  13  Rating            541909 non-null  float64
#  14  Status            541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(8)
# memory usage: 62.0+ MB

# %%
df_temp.to_csv("cleaned_data.csv", index=False)

# %% [markdown]
# EDA

# %%
sns.set(style="dark")
plt.style.use("ggplot")

# %%
df_temp = pd.read_csv("cleaned_data.csv")

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   InvoiceNo         541909 non-null  object
#  1   StockCode         541909 non-null  object
#  2   Description       541909 non-null  object
#  3   Quantity          541909 non-null  int64
#  4   InvoiceDate       541909 non-null  object
#  5   UnitPrice         541909 non-null  float64
#  6   CustomerID        541909 non-null  int64
#  7   Country           541909 non-null  object
#  8   Age               541909 non-null  int64
#  9   Location          541909 non-null  object
#  10  RegistrationDate  541909 non-null  object
#  11  Category          541909 non-null  object
#  12  Stock             541909 non-null  int64
#  13  Rating            541909 non-null  float64
#  14  Status            541909 non-null  object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 62.0+ MB

# %%
df_temp["total_spend"] = df_temp["Quantity"] * df_temp["UnitPrice"]
df_temp.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom   20
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom   20
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom   45
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom   31
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom   19
#
#           Location RegistrationDate     Category  Stock  Rating     Status  \
# 0         Lisaberg       2022-05-06     Clothing     18     4.8    Pending
# 1     Jessicahaven       2022-06-26  Electronics      9     3.9    Pending
# 2      Matthewbury       2023-01-09       Beauty     33     5.0  Delivered
# 3  North Kayleeton       2023-02-11  Electronics     86     4.2    Pending
# 4        Keithside       2023-01-27        Books     21     3.4  Cancelled
#
#    total_spend
# 0        15.30
# 1        20.34
# 2        22.00
# 3        20.34
# 4        20.34

# %%
x = df_temp.groupby(by=['InvoiceDate'])['total_spend'].sum().sort_index(ascending=True).index
y = df_temp.groupby(by=['InvoiceDate'])['total_spend'].sum().sort_index(ascending=True).values

# %%
timeseries_data = pd.DataFrame({'invoice_date': x, 'total_spend': y})
timeseries_data.head()
# Out:
#           invoice_date  total_spend
# 0  2010-12-01 08:26:00       139.12
# 1  2010-12-01 08:28:00        22.20
# 2  2010-12-01 08:34:00       348.78
# 3  2010-12-01 08:35:00        17.85
# 4  2010-12-01 08:45:00       855.86

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming `timeseries_data` is your DataFrame containing `invoice_date` and `total_spend`
timeseries_data['invoice_date'] = pd.to_datetime(timeseries_data['invoice_date'], format="%Y-%m-%d %H:%M:%S")
timeseries_data = timeseries_data.set_index('invoice_date')

# Resample data monthly and sum up `total_spend` for each month
monthly_data = timeseries_data['total_spend'].resample('M').sum()

# Plot the monthly data
plt.figure(figsize=(10, 6))
monthly_data.plot()
plt.title("Total Monthly Spend Over Time")
plt.xlabel("Date")
plt.ylabel("Total Spend")
plt.xticks(rotation=60)
plt.show()
# Out:
# C:\Users\Elite\AppData\Local\Temp\ipykernel_8504\3077172687.py:9: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = timeseries_data['total_spend'].resample('M').sum()

# %%
df_temp.groupby(['Description'])['total_spend'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='Description'>

# %%
df_temp['hour'] = pd.to_datetime(df_temp['InvoiceDate']).dt.hour
df_temp.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom   20
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom   20
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom   45
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom   31
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom   19
#
#           Location RegistrationDate     Category  Stock  Rating     Status  \
# 0         Lisaberg       2022-05-06     Clothing     18     4.8    Pending
# 1     Jessicahaven       2022-06-26  Electronics      9     3.9    Pending
# 2      Matthewbury       2023-01-09       Beauty     33     5.0  Delivered
# 3  North Kayleeton       2023-02-11  Electronics     86     4.2    Pending
# 4        Keithside       2023-01-27        Books     21     3.4  Cancelled
#
#    total_spend  hour
# 0        15.30     8
# 1        20.34     8
# 2        22.00     8
# 3        20.34     8
# 4        20.34     8

# %%
df_temp.groupby('Country')["InvoiceNo"].count().sort_values(ascending=False).head(20)
# Out:
# Country
# United Kingdom     495478
# Germany              9495
# France               8557
# EIRE                 8196
# Spain                2533
# Netherlands          2371
# Belgium              2069
# Switzerland          2002
# Portugal             1519
# Australia            1259
# Norway               1086
# Italy                 803
# Channel Islands       758
# Finland               695
# Cyprus                622
# Sweden                462
# Unspecified           446
# Austria               401
# Denmark               389
# Japan                 358
# Name: InvoiceNo, dtype: int64

# %%
df_temp.groupby('Country')["total_spend"].sum().sort_values(ascending=False).head(20).sort_values(ascending=True).plot(kind='barh')
# Out:
# <Axes: ylabel='Country'>

# %%
df_temp['hour'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='hour'>

# %%
country = "United Kingdom"
df_temp.loc[df_temp['Country'] == f"{country}"].groupby('hour')['total_spend'].sum().plot(kind='bar', color='darkblue')
plt.title(f"Total Spend by Hour in {country}")
# Out:
# Text(0.5, 1.0, 'Total Spend by Hour in United Kingdom')

# %%
df_temp.describe()
# Out:
#             Quantity      UnitPrice     CustomerID            Age  \
# count  541909.000000  541909.000000  541909.000000  541909.000000
# mean        9.552250       4.611114   11476.974671      43.487180
# std       218.081158      96.759853    6777.908326      15.017686
# min    -80995.000000  -11062.060000       0.000000      18.000000
# 25%         1.000000       1.250000   12352.000000      30.000000
# 50%         3.000000       2.080000   14382.000000      43.000000
# 75%        10.000000       4.130000   16255.000000      57.000000
# max     80995.000000   38970.000000   18287.000000      69.000000
#
#                Stock         Rating    total_spend           hour
# count  541909.000000  541909.000000  541909.000000  541909.000000
# mean       50.021769       2.998670      17.987795      13.078729
# std        28.551344       1.154983     378.810824       2.443270
# min         1.000000       1.000000 -168469.600000       6.000000
# 25%        25.000000       2.000000       3.400000      11.000000
# 50%        50.000000       3.000000       9.750000      13.000000
# 75%        75.000000       4.000000      17.400000      15.000000
# max        99.000000       5.000000  168469.600000      20.000000

# %%
df_temp.loc[df_temp['Quantity'] >= 60_000]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61619     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 61619   2011-01-18 10:01:00       1.04       12346  United Kingdom   38
# 540421  2011-12-09 09:15:00       2.08       16446  United Kingdom   52
#
#                Location RegistrationDate Category  Stock  Rating     Status  \
# 61619       Ashleyville       2022-11-26     Home     33     2.6    Pending
# 540421  East Meganburgh       2022-09-22   Beauty     59     1.7  Cancelled
#
#         total_spend  hour
# 61619       77183.6    10
# 540421     168469.6     9

# %%
df_temp.loc[df_temp['UnitPrice'] >= 30_000]
# Out:
#        InvoiceNo StockCode Description  Quantity          InvoiceDate  \
# 222681   C556445         M      Manual        -1  2011-06-10 15:31:00
#
#         UnitPrice  CustomerID         Country  Age          Location  \
# 222681    38970.0       15098  United Kingdom   29  North Staceyland
#
#        RegistrationDate Category  Stock  Rating     Status  total_spend  hour
# 222681       2022-12-29     Toys     19     1.2  Cancelled     -38970.0    15

# %%
df_temp['StockCode'] = df_temp['StockCode'].str.upper()

# %%
df_temp[df_temp['StockCode'] == 'm']
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Age, Location, RegistrationDate, Category, Stock, Rating, Status, total_spend, hour]
# Index: []

# %%
df_temp[df_temp['StockCode'] == 'M']
# Out:
#        InvoiceNo StockCode Description  Quantity          InvoiceDate  \
# 2239      536569         M      Manual         1  2010-12-01 15:35:00
# 2250      536569         M      Manual         1  2010-12-01 15:35:00
# 5684      536865         M      Manual         1  2010-12-03 11:28:00
# 6798      536981         M      Manual         2  2010-12-03 14:26:00
# 7976      537077         M      Manual        12  2010-12-05 11:59:00
# ...          ...       ...         ...       ...                  ...
# 531432    580956         M      Manual         4  2011-12-06 14:23:00
# 533082   C581009         M      Manual        -1  2011-12-07 09:15:00
# 534308   C581145         M      Manual        -1  2011-12-07 13:48:00
# 538321    581405         M      Manual         3  2011-12-08 13:50:00
# 541541   C581499         M      Manual        -1  2011-12-09 10:28:00
#
#         UnitPrice  CustomerID         Country  Age               Location  \
# 2239         1.25       16274  United Kingdom   52           Martinezside
# 2250        18.95       16274  United Kingdom   37            West Robert
# 5684         2.55           0  United Kingdom   20            Jacksonstad
# 6798         0.85       14723  United Kingdom   54         South Michelle
# 7976         0.42       17062  United Kingdom   30              East Leah
# ...           ...         ...             ...  ...                    ...
# 531432       1.25       17841  United Kingdom   20          New Laurabury
# 533082     125.00       16971  United Kingdom   35  East Elizabethchester
# 534308       9.95       17490  United Kingdom   64             Lake Peter
# 538321       0.42       13521  United Kingdom   53           West Heather
# 541541     224.69       15498  United Kingdom   42             Danielberg
#
#        RegistrationDate     Category  Stock  Rating     Status  total_spend  \
# 2239         2022-04-11  Electronics     66     3.8  Cancelled         1.25
# 2250         2023-05-10       Beauty     76     3.6  Cancelled        18.95
# 5684         2022-06-25         Home     93     2.0  Cancelled         2.55
# 6798         2022-08-29     Clothing     97     4.8  Cancelled         1.70
# 7976         2022-01-22       Beauty     14     1.9  Cancelled         5.04
# ...                 ...          ...    ...     ...        ...          ...
# 531432       2023-10-04     Clothing     40     3.1    Pending         5.00
# 533082       2022-11-22       Beauty     80     3.8  Cancelled      -125.00
# 534308       2022-04-10     Clothing     43     3.2  Cancelled        -9.95
# 538321       2022-11-10         Home     70     2.0  Cancelled         1.26
# 541541       2023-09-03       Beauty     77     3.0  Delivered      -224.69
#
#         hour
# 2239      15
# 2250      15
# 5684      11
# 6798      14
# 7976      11
# ...      ...
# 531432    14
# 533082     9
# 534308    13
# 538321    13
# 541541    10
#
# [572 rows x 17 columns]

# %%
df_temp[df_temp['Description'] == 'Manual']['total_spend'].describe()
# Out:
# count      572.000000
# mean      -120.055315
# std       1833.245373
# min     -38970.000000
# 25%        -65.947500
# 50%          1.000000
# 75%          9.315000
# max       4287.630000
# Name: total_spend, dtype: float64

# %%
df_temp['Description'].value_counts().tail(20)
# Out:
# Description
# damages/credits from ASOS.            1
# Found by jackie                       1
# Damages                               1
# VINTAGE BEAD PINK JEWEL STAND         1
# FLOWER SHOP DESIGN MUG                1
# missing?                              1
# PINK CHERRY BLOSSOM CUP & SAUCER      1
# ANT SILVER TURQUOISE BOUDICCA RING    1
# water damaged                         1
# 72 CAKE CASES VINTAGE CHRISTMAS       1
# 4 GOLD FLOCK CHRISTMAS BALLS          1
# SET 10 CARD CHRISTMAS STAMPS 16963    1
# John Lewis                            1
# sold with wrong barcode               1
# CAT WITH SUNGLASSES BLANK CARD        1
# dotcom adjust                         1
# LARGE HEART FLOWERS HOOK              1
# SET 10 CARDS SNOWY ROBIN 17099        1
# POLYESTER FILLER PAD 60x40cm          1
# mailout                               1
# Name: count, dtype: int64

# %%
df_temp.loc[df_temp['Description'] == 'historic computer difference?....se']
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 373660    569341     82600  historic computer difference?....se      -458
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 373660  2011-10-03 14:19:00        0.0           0  United Kingdom   45
#
#           Location RegistrationDate Category  Stock  Rating     Status  \
# 373660  Cindymouth       2023-07-05     Home     45     4.1  Cancelled
#
#         total_spend  hour
# 373660         -0.0    14

# %%
df_temp.loc[df_temp['StockCode'] == '84944']
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 1369      536538     84944  SET OF 6 KASHMIR FOLKART BAUBLES         2
# 6402      536943     84944  SET OF 6 KASHMIR FOLKART BAUBLES         2
# 10102     537225     84944  SET OF 6 KASHMIR FOLKART BAUBLES         4
# 13169     537421     84944  SET OF 6 KASHMIR FOLKART BAUBLES         3
# 16265     537646     84944  SET OF 6 KASHMIR FOLKART BAUBLES         1
# ...          ...       ...                               ...       ...
# 428607    573486     84944  SET OF 6 KASHMIR FOLKART BAUBLES         6
# 428648    573492     84944  SET OF 6 KASHMIR FOLKART BAUBLES         1
# 432975    573901     84944  SET OF 6 KASHMIR FOLKART BAUBLES         4
# 433089    573904     84944  SET OF 6 KASHMIR FOLKART BAUBLES         1
# 441428    574573     84944  SET OF 6 KASHMIR FOLKART BAUBLES         1
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 1369    2010-12-01 13:54:00       4.25       14594  United Kingdom   28
# 6402    2010-12-03 12:11:00       4.25       17884  United Kingdom   31
# 10102   2010-12-05 16:41:00       4.25       12748  United Kingdom   59
# 13169   2010-12-06 15:25:00       4.25       17218  United Kingdom   27
# 16265   2010-12-07 15:39:00       4.25       17591  United Kingdom   45
# ...                     ...        ...         ...             ...  ...
# 428607  2011-10-31 11:40:00       1.65       13186  United Kingdom   65
# 428648  2011-10-31 11:57:00       1.65       13544  United Kingdom   24
# 432975  2011-11-01 14:49:00       1.65       14191  United Kingdom   41
# 433089  2011-11-01 14:54:00       1.65       14505  United Kingdom   20
# 441428  2011-11-04 16:35:00       1.65       14592  United Kingdom   61
#
#                       Location RegistrationDate     Category  Stock  Rating  \
# 1369          North Leslieport       2022-09-13        Books     59     2.0
# 6402              Port Michael       2022-05-26       Beauty     70     1.1
# 10102               New Taylor       2023-07-04       Beauty     34     1.1
# 13169           New Curtisside       2023-03-22         Home     99     3.5
# 16265              Ashleymouth       2023-09-06  Electronics     84     4.3
# ...                        ...              ...          ...    ...     ...
# 428607          West Alexander       2022-05-26     Clothing     16     3.3
# 428648            Jonesborough       2022-12-30         Toys     67     1.7
# 432975  South Christinechester       2023-01-06         Home     17     3.6
# 433089         Christopherbury       2023-03-31         Toys     78     4.3
# 441428            South Joseph       2022-11-24         Toys     86     1.2
#
#            Status  total_spend  hour
# 1369    Delivered         8.50    13
# 6402    Cancelled         8.50    12
# 10102     Pending        17.00    16
# 13169   Cancelled        12.75    15
# 16265   Delivered         4.25    15
# ...           ...          ...   ...
# 428607    Pending         9.90    11
# 428648  Cancelled         1.65    11
# 432975    Pending         6.60    14
# 433089    Pending         1.65    14
# 441428  Delivered         1.65    16
#
# [93 rows x 17 columns]

# %%
df_temp.loc[df_temp['Description'] == 'Missing']
# Out:
#        InvoiceNo StockCode Description  Quantity          InvoiceDate  \
# 165448    550800     22458     Missing       -65  2011-04-20 14:48:00
#
#         UnitPrice  CustomerID         Country  Age     Location  \
# 165448        0.0           0  United Kingdom   37  Maxwellport
#
#        RegistrationDate Category  Stock  Rating     Status  total_spend  hour
# 165448       2023-07-05     Home     22     3.9  Delivered         -0.0    14

# %%
df_temp.loc[df_temp['StockCode'] == '22458'].head()
# Out:
#       InvoiceNo StockCode                 Description  Quantity  \
# 2729     536592     22458  CAST IRON HOOK GARDEN FORK         1
# 7558     537045     22458  CAST IRON HOOK GARDEN FORK         1
# 10524    537237     22458  CAST IRON HOOK GARDEN FORK         1
# 14665    537608     22458  CAST IRON HOOK GARDEN FORK         2
# 19921    537955     22458  CAST IRON HOOK GARDEN FORK         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 2729   2010-12-01 17:06:00       5.06           0  United Kingdom   53
# 7558   2010-12-05 10:54:00       2.55       15038  United Kingdom   27
# 10524  2010-12-06 09:58:00       5.06           0  United Kingdom   33
# 14665  2010-12-07 13:20:00       2.55       15024  United Kingdom   56
# 19921  2010-12-09 11:28:00       2.55       16782  United Kingdom   55
#
#              Location RegistrationDate Category  Stock  Rating     Status  \
# 2729     Shannonburgh       2023-04-16    Books     19     4.6  Delivered
# 7558     Angelicaland       2022-03-11   Beauty     51     2.0  Cancelled
# 10524     Turnerburgh       2022-02-27   Beauty     95     3.5    Pending
# 14665       Mandyfort       2023-07-01    Books     13     2.4    Pending
# 19921  North Margaret       2022-02-21     Toys     72     1.0    Pending
#
#        total_spend  hour
# 2729          5.06    17
# 7558          2.55    10
# 10524         5.06     9
# 14665         5.10    13
# 19921         2.55    11

# %%
df_temp[df_temp['StockCode'].str.contains('90126')]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 27255     538524    90126A   PINK BERTIE MOBILE PHONE CHARM         1
# 265413    560225    90126C  AMBER BERTIE MOBILE PHONE CHARM         2
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 27255   2010-12-13 09:35:00       3.36           0  United Kingdom   54
# 265413  2011-07-15 16:27:00       3.29           0  United Kingdom   47
#
#            Location RegistrationDate  Category  Stock  Rating     Status  \
# 27255   Theresafort       2022-04-05  Clothing     92     4.2  Cancelled
# 265413   Port Logan       2022-11-14    Beauty      6     1.8    Pending
#
#         total_spend  hour
# 27255          3.36     9
# 265413         6.58    16

# %%
df_temp[df_temp['StockCode'].apply(lambda x: len(x) < 5)]['StockCode'].value_counts()
# Out:
# StockCode
# POST    1256
# DOT      710
# M        572
# C2       144
# D         77
# S         63
# CRUK      16
# PADS       4
# B          3
# Name: count, dtype: int64

# %%
df_temp[df_temp['StockCode'] == "M"]
# Out:
#        InvoiceNo StockCode Description  Quantity          InvoiceDate  \
# 2239      536569         M      Manual         1  2010-12-01 15:35:00
# 2250      536569         M      Manual         1  2010-12-01 15:35:00
# 5684      536865         M      Manual         1  2010-12-03 11:28:00
# 6798      536981         M      Manual         2  2010-12-03 14:26:00
# 7976      537077         M      Manual        12  2010-12-05 11:59:00
# ...          ...       ...         ...       ...                  ...
# 531432    580956         M      Manual         4  2011-12-06 14:23:00
# 533082   C581009         M      Manual        -1  2011-12-07 09:15:00
# 534308   C581145         M      Manual        -1  2011-12-07 13:48:00
# 538321    581405         M      Manual         3  2011-12-08 13:50:00
# 541541   C581499         M      Manual        -1  2011-12-09 10:28:00
#
#         UnitPrice  CustomerID         Country  Age               Location  \
# 2239         1.25       16274  United Kingdom   52           Martinezside
# 2250        18.95       16274  United Kingdom   37            West Robert
# 5684         2.55           0  United Kingdom   20            Jacksonstad
# 6798         0.85       14723  United Kingdom   54         South Michelle
# 7976         0.42       17062  United Kingdom   30              East Leah
# ...           ...         ...             ...  ...                    ...
# 531432       1.25       17841  United Kingdom   20          New Laurabury
# 533082     125.00       16971  United Kingdom   35  East Elizabethchester
# 534308       9.95       17490  United Kingdom   64             Lake Peter
# 538321       0.42       13521  United Kingdom   53           West Heather
# 541541     224.69       15498  United Kingdom   42             Danielberg
#
#        RegistrationDate     Category  Stock  Rating     Status  total_spend  \
# 2239         2022-04-11  Electronics     66     3.8  Cancelled         1.25
# 2250         2023-05-10       Beauty     76     3.6  Cancelled        18.95
# 5684         2022-06-25         Home     93     2.0  Cancelled         2.55
# 6798         2022-08-29     Clothing     97     4.8  Cancelled         1.70
# 7976         2022-01-22       Beauty     14     1.9  Cancelled         5.04
# ...                 ...          ...    ...     ...        ...          ...
# 531432       2023-10-04     Clothing     40     3.1    Pending         5.00
# 533082       2022-11-22       Beauty     80     3.8  Cancelled      -125.00
# 534308       2022-04-10     Clothing     43     3.2  Cancelled        -9.95
# 538321       2022-11-10         Home     70     2.0  Cancelled         1.26
# 541541       2023-09-03       Beauty     77     3.0  Delivered      -224.69
#
#         hour
# 2239      15
# 2250      15
# 5684      11
# 6798      14
# 7976      11
# ...      ...
# 531432    14
# 533082     9
# 534308    13
# 538321    13
# 541541    10
#
# [572 rows x 17 columns]

# %%
df_temp.groupby('StockCode')['Description'].value_counts().head(20)
# Out:
# StockCode  Description
# 10002      INFLATABLE POLITICAL GLOBE       71
#            no descreption                    2
# 10080      GROOVY CACTUS INFLATABLE         22
#            check                             1
#            no descreption                    1
# 10120      DOGGY RUBBER                     30
# 10123C     HEARTS WRAPPING TAPE              3
#            no descreption                    1
# 10123G     no descreption                    1
# 10124A     SPOTS ON RED BOOKCOVER TAPE       5
# 10124G     ARMY CAMO BOOKCOVER TAPE          4
# 10125      MINI FUNKY DESIGN TAPES          94
# 10133      COLOURING PENCILS BROWN TUBE    199
#            damaged                           1
# 10134      no descreption                    1
# 10135      COLOURING PENCILS BROWN TUBE    180
# 11001      ASSTD DESIGN RACING CAR PEN     120
# 15030      FAN BLACK FRAME                  13
#            no descreption                    1
# 15034      PAPER POCKET TRAVELING FAN      142
# Name: count, dtype: int64

# %%
most_freq = df_temp.groupby('StockCode')['Description'].agg(lambda x: x.value_counts().idxmax()).reset_index()
df = pd.merge(df_temp, most_freq, on='StockCode', how='left')
df = df.drop(columns=['Description_x'])
df = df.rename(columns={'Description_y': 'Description'})
df = df.reindex(columns=['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'total_spend', 'hour'])

# %%
df_temp.loc[df_temp['Description'] == 'damaged'].head()
# Out:
#        InvoiceNo StockCode Description  Quantity          InvoiceDate  \
# 154656    549935    35915C     damaged       -43  2011-04-13 11:16:00
# 154799    549948    37488A     damaged        -1  2011-04-13 12:55:00
# 166836    550954    47013A     damaged        -2  2011-04-21 16:18:00
# 170484    551302     48189     damaged       -18  2011-04-27 14:55:00
# 180618    552331     22667     damaged       -30  2011-05-09 10:24:00
#
#         UnitPrice  CustomerID         Country  Age         Location  \
# 154656        0.0           0  United Kingdom   30       Randyhaven
# 154799        0.0           0  United Kingdom   59         Ritatown
# 166836        0.0           0  United Kingdom   66     Williamville
# 170484        0.0           0  United Kingdom   27  Port Calvinbury
# 180618        0.0           0  United Kingdom   31      North Kevin
#
#        RegistrationDate     Category  Stock  Rating     Status  total_spend  \
# 154656       2021-12-23  Electronics      3     1.6    Pending         -0.0
# 154799       2022-05-17  Electronics     29     2.0    Pending         -0.0
# 166836       2022-08-14         Toys     55     4.1  Delivered         -0.0
# 170484       2023-10-16        Books     52     4.5  Delivered         -0.0
# 180618       2023-04-01  Electronics     61     2.7  Delivered         -0.0
#
#         hour
# 154656    11
# 154799    12
# 166836    16
# 170484    14
# 180618    10

# %%
df_temp.loc[df_temp['StockCode'].str.contains("10123")]
# Out:
#        InvoiceNo StockCode            Description  Quantity  \
# 5451      536863    10123C  HEARTS WRAPPING TAPE          1
# 109611    545655    10123C  HEARTS WRAPPING TAPE          3
# 140929    548491    10123C  HEARTS WRAPPING TAPE          1
# 150159    549349    10123G         no descreption       -38
# 265293    560213    10123C         no descreption       -18
#
#                 InvoiceDate  UnitPrice  CustomerID         Country  Age  \
# 5451    2010-12-03 11:19:00       0.65       17967  United Kingdom   31
# 109611  2011-03-04 13:58:00       0.65       14670  United Kingdom   24
# 140929  2011-03-31 13:14:00       0.65       14064  United Kingdom   33
# 150159  2011-04-08 11:13:00       0.00           0  United Kingdom   69
# 265293  2011-07-15 15:05:00       0.00           0  United Kingdom   64
#
#              Location RegistrationDate Category  Stock  Rating     Status  \
# 5451     New Markfurt       2023-07-05     Toys     59     3.3  Cancelled
# 109611      Amandaton       2022-02-13    Books     20     5.0  Delivered
# 140929  Jonathanmouth       2023-05-24     Home     35     4.5  Delivered
# 150159     Weissburgh       2023-11-01   Beauty     46     4.2  Delivered
# 265293  Port Nicholas       2023-01-03    Books     56     2.6  Cancelled
#
#         total_spend  hour
# 5451           0.65    11
# 109611         1.95    13
# 140929         0.65    13
# 150159        -0.00    11
# 265293        -0.00    15

# %%
fig, ax = plt.subplots(1, 3, figsize=(10, 3))
ax[0].scatter(x=df_temp['Quantity'], y=df_temp['UnitPrice'])
ax[0].title.set_text('Quantity vs UnitPrice')
ax[1].scatter(x=df_temp['Quantity'], y=df_temp['total_spend'])
ax[1].title.set_text('Quantity vs total_spend')
ax[2].scatter(x=df_temp['UnitPrice'], y=df_temp['total_spend'])
ax[2].title.set_text('UnitPrice vs total_spend')

# %%
df = pd.read_csv("updated_ecommerce_data.csv", encoding='cp1252')

# Clean the data
# df['Description'] = df['Description'].fillna('No Description')
df['CustomerID'] = df['CustomerID'].fillna(0)
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['total_spend'] = df['Quantity'] * df['UnitPrice']

df['InvoiceNo'] = df['InvoiceNo'].astype(str)
df['StockCode'] = df['StockCode'].astype(str)
df['Description'] = df['Description'].astype(str)
df['CustomerID'] = df['CustomerID'].astype(float).astype(int)
df['Country'] = df['Country'].astype(str)
df['total_spend'] = df['total_spend'].astype(float)

df['StockCode'] = df['StockCode'].str.upper()
most_freq = df.groupby('StockCode')['Description'].agg(lambda x: x.value_counts().idxmax()).reset_index()
columns_index = df.columns
df = df.drop(columns=['Description'])
df = pd.merge(df, most_freq, on='StockCode', how='left')
df = df.reindex(columns=columns_index)


df.to_csv("updated_ecommerce_data.csv")
